# %%
from google.colab import drive
import sys

# %load_ext autoreload
# %autoreload 2

drive.mount('/content/drive', force_remount=True)
sys.path.insert(0, '/content/drive/MyDrive/ML_clean')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd './drive/MyDrive/ML_clean'
# Out:
# /content/drive/MyDrive/ML_clean

# %%
# !ls
# Out:
# compute_metrics.py    extract_dataset.py  __pycache__  training.py
# constants.py	      get_prediction.py   run.py       Unet.py
# data		      ML_notebook.ipynb   submissions
# data_augmentation.py  models		  testing.py

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.8/dist-packages (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (4.4.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.13.0+cu116)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->torchmetrics) (3.0.9)

# %%
#cd 'drive/MyDrive/ML_clean'

# %% [markdown]
# # Training pipeline

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import numpy as np
from Unet import Unet 

from constants import *
from extract_dataset import extract_dataset, RoadDataset
from training import run_training
from testing import testing
from compute_metrics import compute_metrics

# %% [markdown]
# ### 1) Extract data and labels
#
# Here, we crop each image into 5 images of size 256 x 256 and we can choose to augment our data (we have initially 100 training images) :

# %%
training_data, training_labels = extract_dataset(augment=True)
# Out:
# Loading 100 images and crop them.
# Augment data.

# %%
print('We now have:', len(training_data), 'images and labels to train our model.')
# Out:
# We now have: 2780 images and labels to train our model.

# %% [markdown]
# ### 2) Split into training and validation set

# %%
# Split in training and validation set
train_data, validation_data, train_labels, validation_labels = train_test_split(training_data, training_labels, test_size=0.2, random_state=42)

# %% [markdown]
# ### 3) Build datasets and Dataloader

# %%
# Build training and validation datasets
train_set = RoadDataset(train_data, train_labels)
validation_set = RoadDataset(validation_data, validation_labels)

# Build dataloader
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(validation_set, 1, shuffle=False)

# %% [markdown]
# ### 4) Start training with a Unet neural network

# %%
# Set parameters to train 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Unet()
num_epochs = 50
optimizer_kwargs = dict(lr=1e-3, weight_decay=1e-3,)
model = model.to(device=device)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.AdamW(model.parameters(), **optimizer_kwargs)

# %%
# Train
model.train()
loss_train_history = []
f1_train_history = []
best_f1 = 0

for epoch in range(1, num_epochs + 1):
    print('\n-------------> epoch: {}'.format(epoch))
    #train_loss, train_acc, lrs = train_epoch(model, optimizer, criterion, train_loader, epoch, device)
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        data = data.permute(0, 3, 1, 2)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)

        pred = torch.round(output)
        # Compute confusion vector between 2 tensors
        confusion_vector = pred / target
        # Compute validation f1 score
        f1_train = compute_metrics(confusion_vector, print_values=False)
        f1_train_history.append(f1_train)
        
        loss.backward()
        optimizer.step()         
        loss_float = loss.item()
        loss_train_history.append(loss_float)

    train_losses = np.mean(loss_train_history)
    epoch_f1 = np.mean(f1_train_history)
    print('Loss score for training:', train_losses)
    print('F1 score for training:', epoch_f1)

    #  Validate Model 
    model.eval()
    loss_val_history = []
    f1_val_history = []
    for data_val, target_val in val_loader:
        data_val, target_val = data_val.to(device), target_val.to(device)
        data_val = data_val.permute(0, 3, 1, 2)

        output_val = model(data_val)

        loss_val = criterion(output_val, target_val).item()
        loss_val_history.append(loss_val)

        pred_val = torch.round(output_val)

        # Compute confusion vector between 2 tensors
        confusion_vector_val = pred_val / target_val
        # Compute validation f1 score
        f1_val = compute_metrics(confusion_vector_val, print_values=False)
        f1_val_history.append(f1_val)
    
    val_loss = np.mean(loss_val_history)
    epoch_f1_val = np.mean(f1_val_history)
    print('\nLoss score for validation:', val_loss)
    print('F1 score for validation:', epoch_f1_val)

    # Save model if best
    if epoch_f1_val > best_f1:
        best_f1 = epoch_f1_val
        best_model = model
        torch.save(model.state_dict(), 'models/best_model_f1.pth')
        print('-------------> NEW BEST MODEL SAVED')
# Out:
# -------------> epoch: 1
# Loss score for training: 0.48706881305296645
# F1 score for training: 0.0023690339090155312
#
# Loss score for validation: 0.45875670500903676
# F1 score for validation: 0.0
#
# -------------> epoch: 2
# Loss score for training: 0.45974517726212094
# F1 score for training: 0.02529816310120632
#
# Loss score for validation: 0.40347151527945085
# F1 score for validation: 0.45174707118585894
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 3
# Loss score for training: 0.427797968439061
# F1 score for training: 0.19424410038085768
#
# Loss score for validation: 0.31374209994624414
# F1 score for validation: 0.5505369179319721
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 4
# Loss score for training: 0.39217635782824145
# F1 score for training: 0.3125667643114033
#
# Loss score for validation: 0.24978113444455022
# F1 score for validation: 0.7007992590768564
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 5
# Loss score for training: 0.36259263648832446
# F1 score for training: 0.3967284587198611
#
# Loss score for validation: 0.2303700508518821
# F1 score for validation: 0.7238764895231674
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 6
# Loss score for training: 0.336346400191458
# F1 score for training: 0.4606597190711598
#
# Loss score for validation: 0.18926836004005007
# F1 score for validation: 0.7452790418411754
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 7
# Loss score for training: 0.31462868894972024
# F1 score for training: 0.5102457031282502
#
# Loss score for validation: 0.1874930877824776
# F1 score for validation: 0.761091701053012
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 8
# Loss score for training: 0.2968142732187248
# F1 score for training: 0.5488884425969006
#
# Loss score for validation: 0.17932647357043843
# F1 score for validation: 0.7668197552551539
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 9
# Loss score for training: 0.28162069105320603
# F1 score for training: 0.5807469490140612
#
# Loss score for validation: 0.1519573881171925
# F1 score for validation: 0.7920214047899271
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 10
# Loss score for training: 0.2676381965924939
# F1 score for training: 0.608082660557047
#
# Loss score for validation: 0.1541522075566973
# F1 score for validation: 0.7913608488030163
#
# -------------> epoch: 11
# Loss score for training: 0.25523867021985425
# F1 score for training: 0.6315717726667548
#
# Loss score for validation: 0.13951254765736673
# F1 score for validation: 0.8128049246781728
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 12
# Loss score for training: 0.24392664432972314
# F1 score for training: 0.6521803813483058
#
# Loss score for validation: 0.12674137815614447
# F1 score for validation: 0.8143704585390149
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 13
# Loss score for training: 0.2336040663790096
# F1 score for training: 0.6703251670824176
#
# Loss score for validation: 0.12611388639920046
# F1 score for validation: 0.8224587919441146
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 14
# Loss score for training: 0.22485897208411795
# F1 score for training: 0.6858139994135274
#
# Loss score for validation: 0.13174760072503214
# F1 score for validation: 0.812940536444143
#
# -------------> epoch: 15
# Loss score for training: 0.21657465001840673
# F1 score for training: 0.699986732087292
#
# Loss score for validation: 0.14182603422158138
# F1 score for validation: 0.8081637878843024
#
# -------------> epoch: 16
# Loss score for training: 0.2091178718548965
# F1 score for training: 0.7125682380516408
#
# Loss score for validation: 0.11904267950800373
# F1 score for validation: 0.8349839403333861
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 17
# Loss score for training: 0.20175992162094952
# F1 score for training: 0.7244222301053429
#
# Loss score for validation: 0.11237855843553511
# F1 score for validation: 0.8394941841295662
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 18
# Loss score for training: 0.1947830970705056
# F1 score for training: 0.7354242964340598
#
# Loss score for validation: 0.11123308175278286
# F1 score for validation: 0.8462370065477479
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 19
# Loss score for training: 0.18825587096515817
# F1 score for training: 0.7455484084685698
#
# Loss score for validation: 0.10787272293232131
# F1 score for validation: 0.844059829392693
#
# -------------> epoch: 20
# Loss score for training: 0.1821504228165467
# F1 score for training: 0.7548943634042539
#
# Loss score for validation: 0.10772449193381944
# F1 score for validation: 0.8476530744957727
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 21
# Loss score for training: 0.17644378676775713
# F1 score for training: 0.7635325117108996
#
# Loss score for validation: 0.11277024399359427
# F1 score for validation: 0.8503847013853256
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 22
# Loss score for training: 0.1711011972592655
# F1 score for training: 0.771548380321567
#
# Loss score for validation: 0.11571296268897209
# F1 score for validation: 0.8536508251286089
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 23
# Loss score for training: 0.166231287050786
# F1 score for training: 0.7788674164986308
#
# Loss score for validation: 0.11719999891915545
# F1 score for validation: 0.8472602391607854
#
# -------------> epoch: 24
# Loss score for training: 0.16160298630872147
# F1 score for training: 0.7857449584727936
#
# Loss score for validation: 0.12174717390095904
# F1 score for validation: 0.8525535943132391
#
# -------------> epoch: 25
# Loss score for training: 0.1572448834305187
# F1 score for training: 0.7921580879359573
#
# Loss score for validation: 0.1156589838706446
# F1 score for validation: 0.8589217470580143
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 26
# Loss score for training: 0.1529372849346535
# F1 score for training: 0.7983856133224954
#
# Loss score for validation: 0.13033243532407557
# F1 score for validation: 0.8521064816724317
#
# -------------> epoch: 27
# Loss score for training: 0.1488884963386025
# F1 score for training: 0.8042078781757005
#
# Loss score for validation: 0.11915967795971155
# F1 score for validation: 0.8587831119580032
#
# -------------> epoch: 28
# Loss score for training: 0.1450528943363696
# F1 score for training: 0.8096913662146695
#
# Loss score for validation: 0.13112479976712574
# F1 score for validation: 0.8588083220294803
#
# -------------> epoch: 29
# Loss score for training: 0.14144124688880522
# F1 score for training: 0.8148464507844445
#
# Loss score for validation: 0.13499014364243267
# F1 score for validation: 0.8430405614026321
#
# -------------> epoch: 30
# Loss score for training: 0.13837828775041466
# F1 score for training: 0.8193831978708425
#
# Loss score for validation: 0.3499365388449255
# F1 score for validation: 0.7441576697752638
#
# -------------> epoch: 31
# Loss score for training: 0.13825929428613512
# F1 score for training: 0.8207934279397405
#
# Loss score for validation: 0.14021323671244212
# F1 score for validation: 0.8158280127552023
#
# -------------> epoch: 32
# Loss score for training: 0.13632524637513788
# F1 score for training: 0.82402673327847
#
# Loss score for validation: 0.1195623312922167
# F1 score for validation: 0.841702793742854
#
# -------------> epoch: 33
# Loss score for training: 0.1336445567614929
# F1 score for training: 0.8279000249049052
#
# Loss score for validation: 0.12057674517764148
# F1 score for validation: 0.8553942841592498
#
# -------------> epoch: 34
# Loss score for training: 0.13080537307083645
# F1 score for training: 0.8318640343206513
#
# Loss score for validation: 0.13360312277593214
# F1 score for validation: 0.8595054692729326
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 35
# Loss score for training: 0.1279703634386195
# F1 score for training: 0.8357557596754585
#
# Loss score for validation: 0.13675302763604874
# F1 score for validation: 0.8644574465394851
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 36
# Loss score for training: 0.1251971575451626
# F1 score for training: 0.8395249787077731
#
# Loss score for validation: 0.14898802566924244
# F1 score for validation: 0.862531353869156
#
# -------------> epoch: 37
# Loss score for training: 0.12252518700933018
# F1 score for training: 0.8431416167696499
#
# Loss score for validation: 0.14793624065842292
# F1 score for validation: 0.8653131023963665
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 38
# Loss score for training: 0.11997091439995168
# F1 score for training: 0.8465934454739086
#
# Loss score for validation: 0.15603443976654727
# F1 score for validation: 0.8660268910088668
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 39
# Loss score for training: 0.11750949452686323
# F1 score for training: 0.8499056212341859
#
# Loss score for validation: 0.16494552345370228
# F1 score for validation: 0.8668596443734156
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 40
# Loss score for training: 0.11515593961829307
# F1 score for training: 0.8530681099618306
#
# Loss score for validation: 0.1573398260365643
# F1 score for validation: 0.8634341865231162
#
# -------------> epoch: 41
# Loss score for training: 0.11291160790687994
# F1 score for training: 0.856080379638572
#
# Loss score for validation: 0.15963395438402406
# F1 score for validation: 0.8675342353106078
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 42
# Loss score for training: 0.1107648635955043
# F1 score for training: 0.8589601676137333
#
# Loss score for validation: 0.15862942858209678
# F1 score for validation: 0.8680688825672107
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 43
# Loss score for training: 0.10869152455841376
# F1 score for training: 0.8617321330979978
#
# Loss score for validation: 0.1778872992252258
# F1 score for validation: 0.8677546138763694
#
# -------------> epoch: 44
# Loss score for training: 0.1067033116638714
# F1 score for training: 0.8643876504842938
#
# Loss score for validation: 0.18323276357503634
# F1 score for validation: 0.8669060973407712
#
# -------------> epoch: 45
# Loss score for training: 0.10479603250854187
# F1 score for training: 0.8669322616955004
#
# Loss score for validation: 0.16985037622850618
# F1 score for validation: 0.8674708743008294
#
# -------------> epoch: 46
# Loss score for training: 0.10296188637047358
# F1 score for training: 0.8693764493217316
#
# Loss score for validation: 0.17791256318870394
# F1 score for validation: 0.8682308933292421
# -------------> NEW BEST MODEL SAVED
#
# -------------> epoch: 47
# Loss score for training: 0.1012251256810712
# F1 score for training: 0.8716966820799753
#
# Loss score for validation: 0.18994155867758328
# F1 score for validation: 0.8636434644266076
#
# -------------> epoch: 48
# Loss score for training: 0.09957133177307723
# F1 score for training: 0.8739094947892284
#
# Loss score for validation: 0.1652403473287839
# F1 score for validation: 0.8657946012363125
#
# -------------> epoch: 49
# Loss score for training: 0.09795272652174107
# F1 score for training: 0.8760659118171304
#
# Loss score for validation: 0.17415204545395746
# F1 score for validation: 0.8671750673631644
#
# -------------> epoch: 50
# Loss score for training: 0.09636158337937199
# F1 score for training: 0.8781728487642562
#
# Loss score for validation: 0.1850694867708225
# F1 score for validation: 0.8674960346478231

# %% [markdown]
# Based on the f1 score we save the best model and we can then apply it to our testing images

# %% [markdown]
# ## Testing pipeline

# %%
import run
